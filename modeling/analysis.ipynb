# %%
import shap
import pickle
import pandas as pd

# %%
with open('model.pickle','rb') as file:
    model = pickle.load(file)

# %%
data = pd.read_csv('dataset.csv')
target = data['price_gold']
feature = data.drop('price_gold',axis=1)

# %%
explainer = shap.Explainer(model)
shap_val = explainer(feature)
shap.plots.beeswarm(shap_val)

# %%
shap.plots.waterfall(shap_val[50])

# %%
dataset = pd.read_csv('modeldata.csv')

# %%
dataset.index = dataset['date']
dataset.drop('index',axis=1,inplace=True)

# %%
dataset[dataset['date']> '2021-07-01']['price_gold'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dataset[dataset['date']> '2020-01-01']['kospi'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dataset[dataset['date']> '2021-07-01']['kosdaq'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dataset[dataset['date']> '2021-07-01']['sp500'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dataset[dataset['date']> '2021-07-01']['price_btc'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dataset[dataset['date']> '2021-07-01']['exchangerate'].plot()
# Out:
# <AxesSubplot:xlabel='date'>
